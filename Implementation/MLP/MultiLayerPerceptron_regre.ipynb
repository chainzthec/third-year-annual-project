# %% [markdown]
# # Perceptron Multi Couches - Regre

# %%
import CLibrary as CLib
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
import numpy as np
import math
from mpl_toolkits.mplot3d import Axes3D

# %%
def get(i, l):
    return [z[i] for z in l]

# %% [markdown]
# ## Single Class

# %% [markdown]
# ### Linear Simple 2D :
# - <font color='green'>Linear Model : OK</font>
# - <font color='green'>MLP (1, 1) : OK</font>

# %%
X = np.array([[1],[2]])
Y = np.array([2,3])

XF = X.flatten().tolist()
YF = Y.flatten().tolist()

N = [1, 1]  
mlpReg_1 = CLib.init(N)

sampleCount = 2

CLib.fit_regression(
    mlpReg_1,
    XF, 
    YF,
    sampleCount,
    10000,
    0.01 
)

for x, y in zip(X, Y):
    plt.scatter(
        x,
        y,
        color='red'
    )

for i in range(0, 300):
    i /= 100
    value = CLib.predict(mlpReg_1, [i], N, False);
    plt.scatter(i, value, marker=',', color='blue', s=1)

plt.show()
plt.clf()

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

XF = X.flatten().tolist()
YF = Y.flatten().tolist()

N = [4, 1]  
mlpReg_1 = CLib.init(N)

sampleCount = 3

CLib.fit_regression(
    mlpReg_1,
    XF, 
    YF,
    sampleCount,
    10000,
    0.1 
)

for x, y in zip(X, Y):
    plt.scatter(
        x,
        y,
        color='red'
    )

for i in range(0, 300):
    i /= 100
    value = CLib.predict(mlpReg_1, [i], N, False);
    plt.scatter(i, value, marker=',', color='blue', s=1)

plt.show()
plt.clf()

# %% [markdown]
# ### Non Linear Simple 2D :
# - <font color='green'>Linear Model : OK</font>
# - <font color='green'>MLP (1, ?, 1) : OK</font>

# %%
X = np.array([ [1], [2], [3] ]) 
Y = np.array([ 2, 3, 2.5 ])

XF = X.flatten().tolist()
YF = Y.flatten().tolist()

N = [1, 4, 1]  
mlpReg_2 = CLib.init(N)

sampleCount = 3

CLib.fit_regression(
    mlpReg_2,
    XF, 
    YF,
    sampleCount,
    10000,
    0.1 
)

for x, y in zip(X, Y):
    plt.scatter(
        x,
        y,
        color='red'
    )

for i in range(0, 300):
    i /= 100
    plt.scatter(i, CLib.predict(mlpReg_2, [i], N), marker=',', color='blue', s=1)

plt.show()
plt.clf()

# %% [markdown]
# ### Linear Simple 3D :
# - <font color='green'>Linear Model : OK</font>
# - <font color='green'>MLP (2, 1) : OK</font>

# %%
X = np.array([ [1, 1], [2, 2], [3, 3] ]) 
Y = np.array([ 1, 2, 3 ])

XF = X.flatten().tolist()
YF = Y.flatten().tolist()

N = [2, 1]  
mlpReg_3 = CLib.init(N)

sampleCount = 3

CLib.fit_regression(
    mlpReg_3,
    XF, 
    YF,
    sampleCount,
    10000,
    0.1 
)

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0], X[:,1], Y, color="red")

XX, YY, ZZ = [], [], []

for i in range(0, 1000, 10):
    for j in range(0, 1000, 10):
        i /= 100
        j /= 100
        XX.append(i)
        YY.append(j)
        zz = CLib.predict(mlpReg_3, [i, j], N)
        ZZ.append(zz[0])

ax.plot_trisurf(XX, YY, ZZ, lw=0, color="grey", alpha=0.5)
plt.show()

# %% [markdown]
# ### Linear Tricky 3D :
# - <font color='green'>Linear Model : OK</font>
# - <font color='green'>MLP (2, 1) : OK</font>

# %%
X = np.array([ [1, 1], [2, 2], [3, 1] ]) 
Y = np.array([ 2, 3, 2.5 ])

XF = X.flatten().tolist()
YF = Y.flatten().tolist()

N = [2, 1]  
mlpReg_4 = CLib.init(N)

sampleCount = 3

CLib.fit_regression(
    mlpReg_4,
    XF, 
    YF,
    sampleCount,
    10000,
    0.1 
)

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0], X[:,1], Y, color="red")

XX, YY, ZZ = [], [], []

for i in range(0, 500, 10):
    for j in range(0, 500, 10):
        i /= 100
        j /= 100
        XX.append(i)
        YY.append(j)
        zz = CLib.predict(mlpReg_4, [i, j], N)
        ZZ.append(zz[0])

ax.plot_trisurf(XX, YY, ZZ, lw=0, color="grey", alpha=0.5)
plt.show()

# %% [markdown]
# ### Non Linear Simple 3D :
# - <font color='red'>Linear Model : KO</font>
# - <font color='green'>MLP (2, 2, 1) : OK</font>

# %%
X = np.array([ [1, 0], [0, 1], [1, 1], [0, 0] ]) 
Y = np.array([ 2, 1, -2, -1 ])

XF = X.flatten().tolist()
YF = Y.flatten().tolist()

N = [2, 2, 1]  
mlpReg_5 = CLib.init(N)

sampleCount = 4

CLib.fit_regression(
    mlpReg_5,
    XF, 
    YF,
    sampleCount,
    50000,
    0.01 
)

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0], X[:,1], Y, color="red")

XX, YY, ZZ = [], [], []

for i in range(0, 500, 10):
    for j in range(0, 500, 10):
        i /= 100
        j /= 100
        XX.append(i)
        YY.append(j)
        zz = CLib.predict(mlpReg_5, [i, j], N)
        ZZ.append(zz[0])

ax.plot_trisurf(XX, YY, ZZ, lw=0, color="grey", alpha=0.5)
plt.show()
